# %% [markdown]
# Spin Physics
#
# CompassMR
#
#
# FID, frequency & resonance excitation (set frequency.yaml, use find frequency) - this was done when system is starting up so field is still drifting!
#
# Wobble to show resonance as well
#
# Sample 2D and 3D RARE scans (default 3D RARE with 8 averages for plant)

# %% [markdown]
# Bloch Equation
#
# Bloch Simulator
#
# Flip angle versus signal - Pulse Calibration, Relaxation - T1-T2 IRCPMG

# %% [markdown]
# MRI System, Magnetic Fields and RF Coils
#
# Tuning RF coil - Wobble, testing signal afterwards
#
# turn on gradients - 1D SE, this was ok, helped to use slice select to isolate different spatial locations and show different frequencies

# %% [markdown]
# Pulse Sequence, Signal Equation
#
# Off-resonance (FID, show real/imag)
#
# T1 and T2 contrast
#
# Inversion Recovery (2D RARE with slice select, monitor change in signal)

# %% [markdown]
# Contrast Mechanisms
#
# T1 and T2 of pure water, added Gd (1 drop enough!), and shim sample
#
# inversion recovery

# %% [markdown]
# In Vivo Contrast Mechanisms
#
# DRCMR Bloch Simulator - T2* and spin-echo demos
#
#
# Shimming - T2* over the entire sample was big change;
#
# Contrast in samples - salami/meat, tomato
#
# add susceptibility objects to doped water

# %% [markdown]
# RF Pulses
#
# DRCMR Bloch Simulator - hard vs sinc, slice excitation, slice refocusing
#
# 2D imaging - projection, add slice, move slice

# %% [markdown]
# Spatial Encoding
#
# 1D SE profile -- create point object with large FOV = 0.04, slice select
#
# 2D RARE - shows kx and ky projects, added slice select adjust FE/PE parameters

# %% [markdown]
# Image Reconstruction and k-space
#
# "DRCMR Bloch Simulator - refocusing of gradients
#
# Online simulators - MRI sampling tool, and FFT webcam"
#
# 1D SE profile -- create rect object with slice select, stretch/shrink object, offset to show Fourier properties

# %% [markdown]
# Image Characteristics
#
# 2D RARE - modify parameters and visualize image + SNR changes
# Due to Teeff/ETL, this maybe easier in FISP?
#
# See Lab notebook for better details

# %% [markdown]
# Volumetric Imaging
#
# 2D versus 3D scan - tried to match scan parameters but not successful.  Emphasized 3D visualization

# %% [markdown]
# Multiple Spin-Echo Sequences
#
# Bloch Simulator - repeated excitations - 90-[180], with mixed matter, inhomogeneity
#
#
# RARE sequence parameters - ETL, TEeff, interleaving artifacts.  Made a very short T2 phantom (3 drops of Gd in pure water), and observed edge enhancement PSF effects in RARE!

# %% [markdown]
# EPI

# %% [markdown]
# Fast Gradient Echo Imaging
#
# 3D FISP sequence demo: unexpected contrast changes with flip angle!
#
# Bloch Simulator - repeated excitations +-90 with mixed matter

# %% [markdown]
# Artifacts
#
# "Artifacts introduced:
# off-resonance displacement - 2D RARE in X-Y (circle object), change frequency.yaml for chemical shift, change shims.yaml (y shim for shear, x2z2 creates stretch/pileup!)
# susceptibility object artifacts (didn't try)
# Ghosting - created ETL=NPE/2 with TR=1 in 2D RARE, then slide sample in and out between repetitions!"
#
# artifacts - aliasing (FOV.yaml), ringing (turn off Gaussian filter), susceptibility objects - 3D FISP ok, was RARE better?, chemical shift - very hard to see in spectrum, no image effect, maybe oil/water phantom would be better, motion - ok with multi-shot RARE...

# %% [markdown]
# Motion
#
# Diffusion
#
# diffusion notebooks - these are usable!  Celery phantom ok
#
# Flow
#
# flow phantom and notebooks
