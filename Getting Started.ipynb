# %% [markdown]
# # ilumr Tabletop MRI: Getting Started

# %% [markdown]
# Note: Put on 45 minutes before desired start time. System has to reach 30C (takes 15 minutes), and maintain for 30 minutes.
# First use the sample holder and black rubber thing to make sure the sample is aligned in the window.
#
# Connect via WiFi
# WiFi name: ilumr-RLI02302027
# Password: RLI02302027
#
# Open Interface:b
# http://192.168.0.4/

# %% [markdown]
# ## Samples
#
# ### 10 mm samples
#
# 002 - thin slice
#
# 003 - 2 thin slices
#
# 004 - 2 vertical cylinders
#
# 005 - 3 vertical cylinders at different depths ("3 cell phantom", for Lab 3 Selective Excitation)
#
# 006 - Some detailed pattern, "mystery phantom" from Lab 3 find hidden text
